# %%
#roboflow dataset from tutorial https://www.youtube.com/watch?v=kbMfgVZn05U  # https://universe.roboflow.com/nam-nhat/trash-dvdrr/dataset/5

# %%
#dataset with handwriting numbers  # https://universe.roboflow.com/new-workspace-pl2m7/multiple_digits/dataset/5
#another set  # https://universe.roboflow.com/aiwork/aidigit/dataset/5
#aka mnist  # https://universe.roboflow.com/rodrigo-domingues/handwritten-numbers/dataset/2
#another mnist  # https://universe.roboflow.com/mnist-ogwoy/mnist-ghkvi/dataset/3  # слишком четкие цифры

#car numbers in bad quality  # https://universe.roboflow.com/el-mejjad-salim/train-qxa4w/dataset/1/images/01684fdcffd6e48152f89b732343ea87
#SVHN like docTR  # https://universe.roboflow.com/project/svhn-4hif1/dataset/1

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/MyDrive
# !git clone http://github.com/augmentedstartups/yolov7.git
# %cd yolov7
# !pip install -r requirements.txt
# !pip install roboflow

# %%
# %cd /content/gdrive/MyDrive/yolov7

from roboflow import Roboflow
rf = Roboflow(api_key="fI73miwjJ24LMhypYxxi")
project = rf.workspace("new-workspace-pl2m7").project("multiple_digits")
dataset = project.version(5).download("yolov7")
# Out:
# /content/gdrive/MyDrive/yolov7
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Multiple_Digits-5 in yolov7pytorch:: 100%|██████████| 409/409 [01:31<00:00,  4.45it/s]

# %%
# %cd /content/gdrive/MyDrive/yolov7 #another set

from roboflow import Roboflow
rf = Roboflow(api_key="fI73miwjJ24LMhypYxxi")
project = rf.workspace("aiwork").project("aidigit")
dataset = project.version(5).download("yolov7")
# Out:
# [Errno 2] No such file or directory: '/content/gdrive/MyDrive/yolov7 #another set'
# /content/gdrive/MyDrive/yolov7
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to aidigit-5 in yolov7pytorch:: 100%|██████████| 252/252 [00:01<00:00, 141.49it/s]

# %%
# %%bash
# wget -P /content/gdrive/MyDrive/yolov7 http://github.com/WongKinYiu/yolov7/releases/download/v0.1/yolov7.pt  #/content/yolov7

# %%
# %cd /content/gdrive/MyDrive/yolov7
# !python train.py --batch 16 --cfg cfg/training/yolov7.yaml --epochs 4 --data {dataset.location}/data.yaml --weights '/content/gdrive/MyDrive/yolov7/runs/train/exp5/weights/epoch_073.pt' --device 0

# %%
from IPython.display import Image

# %%
display(Image('/content/gdrive/MyDrive/yolov7/runs/train/exp5/F1_curve.png', width=500, height=400))
display(Image('/content/gdrive/MyDrive/yolov7/runs/train/exp5/PR_curve.png', width=500, height=400))
display(Image('/content/gdrive/MyDrive/yolov7/runs/train/exp5/confusion_matrix.png', width=500, height=500))

# %%
dataset='/content/gdrive/MyDrive/yolov7/Multiple_Digits-5/valid/images' #for test

# %%
# %cd /content/gdrive/MyDrive/yolov7
# Out:
# /content/gdrive/MyDrive/yolov7

# %%
# !python detect.py --weights /content/gdrive/MyDrive/yolov7/runs/train/exp5/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/yolov7/Multiple_Digits-5/valid/images #{dataset.location}/valid/images
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.1, device='', exist_ok=False, img_size=640, iou_thres=0.45, name='exp', no_trace=False, nosave=False, project='runs/detect', save_conf=False, save_txt=False, source='/content/gdrive/MyDrive/yolov7/Multiple_Digits-5/valid/images', update=False, view_img=False, weights=['/content/gdrive/MyDrive/yolov7/runs/train/exp5/weights/epoch_073.pt'])
# YOLOR 🚀 v0.1-104-g941b94c torch 1.12.1+cu113 CUDA:0 (Tesla T4, 15109.75MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# /usr/local/lib/python3.7/dist-packages/torch/functional.py:478: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2894.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# ...

# %%
import glob
from IPython.display import Image, display

i=0
limit=10000
for imageName in glob.glob('/content/gdrive/MyDrive/yolov7/runs/detect/exp/*.jpg'):
  if i <limit:
    display(Image(filename=imageName))
    print("\n")
  i+=1

# %%
classes_to_filter=None  #need to be ['word', 'anotherWord'] or None

opt={
    "weights": "runs/train/exp/weights/best.pt",
    "yaml": "Trash-5/data.yaml",
    "img-size": 640,
    "conf-thres": 0.25,
    "iou-thres": 0.45,
    "device": '0', #can be 0,1,2,3 or cpu
    "classes": classes_to_filter #this class will not show
}

# %%
# !python detect.py --weights /content/gdrive/MyDrive/yolov7/runs/train/exp5/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/Numbers/640_white/v1
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.1, device='', exist_ok=False, img_size=640, iou_thres=0.45, name='exp', no_trace=False, nosave=False, project='runs/detect', save_conf=False, save_txt=False, source='/content/gdrive/MyDrive/Numbers/640_white/v1', update=False, view_img=False, weights=['/content/gdrive/MyDrive/yolov7/runs/train/exp5/weights/best.pt'])
# YOLOR 🚀 v0.1-104-g941b94c torch 1.12.1+cu113 CUDA:0 (Tesla T4, 15109.75MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# /usr/local/lib/python3.7/dist-packages/torch/functional.py:478: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2894.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Model Summary: 314 layers, 36530318 parameters, 6194944 gradients, 103.3 GFLOPS
# ...

# %%
import glob
from IPython.display import Image, display

i=0
limit=10000
for imageName in glob.glob('/content/gdrive/MyDrive/yolov7/runs/detect/exp7/*.jpg'):
  if i <limit:
    display(Image(filename=imageName))
    print("\n")
  i+=1

# %%
# %cd /content/gdrive/MyDrive/yolov7
# !python train.py --batch 16 --cfg cfg/training/yolov7.yaml --epochs 4 --data '/content/gdrive/MyDrive/yolov7/aidigit-5/data.yaml' --weights '/content/gdrive/MyDrive/yolov7/runs/train/exp5/weights/epoch_073.pt' --device 0
# Out:
# /content/gdrive/MyDrive/yolov7
# YOLOR 🚀 v0.1-104-g941b94c torch 1.12.1+cu113 CUDA:0 (Tesla T4, 15109.75MB)
#
# Namespace(adam=False, artifact_alias='latest', batch_size=16, bbox_interval=-1, bucket='', cache_images=False, cfg='cfg/training/yolov7.yaml', data='/content/gdrive/MyDrive/yolov7/aidigit-5/data.yaml', device='0', entity=None, epochs=4, evolve=False, exist_ok=False, freeze=[0], global_rank=-1, hyp='data/hyp.scratch.p5.yaml', image_weights=False, img_size=[640, 640], label_smoothing=0.0, linear_lr=False, local_rank=-1, multi_scale=False, name='exp', noautoanchor=False, nosave=False, notest=False, project='runs/train', quad=False, rect=False, resume=False, save_dir='runs/train/exp17', save_period=-1, single_cls=False, sync_bn=False, total_batch_size=16, upload_dataset=False, weights='/content/gdrive/MyDrive/yolov7/runs/train/exp5/weights/epoch_073.pt', workers=8, world_size=1)
# tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# ...

# %%
pip install -r /content/drive/MyDrive/yolov7/requirements.txt

# %%
# !pip install onnx
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 13.1 MB 6.1 MB/s
# ...

# %%
import onnx

# %%
# %cd /content/drive/MyDrive/yolov7
# !python export.py --weights /content/drive/MyDrive/yolov7/runs/train/exp5/weights/best.pt --img-size 640 --batch-size 1
# Out:
# /content/drive/MyDrive/yolov7
# Import onnx_graphsurgeon failure: No module named 'onnx_graphsurgeon'
# Namespace(batch_size=1, conf_thres=0.25, device='cpu', dynamic=False, dynamic_batch=False, end2end=False, fp16=False, grid=False, img_size=[640, 640], include_nms=False, int8=False, iou_thres=0.45, max_wh=None, simplify=False, topk_all=100, weights='/content/drive/MyDrive/yolov7/runs/train/exp5/weights/best.pt')
# YOLOR 🚀 v0.1-104-g941b94c torch 1.12.1+cu113 CPU
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# Model Summary: 314 layers, 36530318 parameters, 6194944 gradients
#
# Starting TorchScript export with torch 1.12.1+cu113...
# /content/drive/MyDrive/yolov7/utils/general.py:724: TracerWarning: Iterating over a tensor might cause the trace to be incorrect. Passing a tensor of different shape won't change the number of iterations executed (and might lead to errors or silently give incorrect results).
# ...

# %%
import glob
from IPython.display import Image, display
from PIL import Image

img=[]
for imageName in glob.glob('/content/drive/MyDrive/Prices/416/*.jpg'): #assuming JPG
    a=Image.open(imageName)
    img.append(a)
    print(f'{imageName}')
    

from torchvision.transforms import ToTensor

imTens=[]
for i in img:
  im=ToTensor()(i).unsqueeze(0)  
  imTens.append(im)
# Out:
# /content/drive/MyDrive/Prices/416/1_1.jpg
# /content/drive/MyDrive/Prices/416/2_1.jpg
# /content/drive/MyDrive/Prices/416/3_1.jpg
# /content/drive/MyDrive/Prices/416/5_1.jpg

# %%
import torch
scripted_model2 = torch.jit.load('/content/drive/MyDrive/yolov7/runs/train/exp5/weights/best.torchscript.ptl')

# %%
scripted_model3 = torch.jit.load('/content/drive/MyDrive/yolov7/runs/train/exp5/weights/best.torchscript.pt')

# %%
ss=scripted_model3(imTens[3])
ss
# Out:
# [tensor([], size=(0, 6))]

# %%
scripted_model2
# Out:
# RecursiveScriptModule(original_name=Model)

# %%
aaa=scripted_model2(imTens[3])
aaa
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py:1130: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  ../c10/core/TensorImpl.h:1405.)
#   return forward_call(*input, **kwargs)
# [tensor([[[[[ 1.0283e-02, -1.0151e-02, -1.1824e-01,  ..., -4.1222e-02,
#               1.0244e-02, -8.3711e-02],
#             [ 9.3406e-03, -1.3390e-02, -1.3588e-01,  ..., -4.4298e-02,
#               1.0290e-02, -7.7024e-02],
#             [ 6.1805e-03, -1.1894e-02, -1.3591e-01,  ..., -4.6010e-02,
#               1.0446e-02, -8.1363e-02],
#             ...,
#             [ 6.7292e-03, -9.3040e-03, -1.4807e-01,  ..., -4.2079e-02,
#               1.2673e-02, -1.0877e-01],
#             [ 7.6628e-03, -1.0038e-02, -1.5263e-01,  ..., -4.1988e-02,
#               1.1638e-02, -1.1405e-01],
# ...

# %%
from drive.MyDrive.yolov7.utils.general import non_max_suppression_kpt
